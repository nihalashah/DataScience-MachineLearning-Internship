# %%
import pandas as pd

# %%
sales=pd.read_csv('sales.csv')
sales
# Out:
#                                Region                Country        Item_Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub_Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub_Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub_Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub_Saharan Africa             Mozambique        Household
#
# ...

# %%
sales.columns
# Out:
# Index(['Region', 'Country', 'Item_Type', 'Sales_Channel', 'Order_Priority',
#        'Ship_Date', 'Unit_Cost', 'Total_Revenue', 'Total_Profit', 'Unnamed: 9',
#        'Unnamed: 10'],
#       dtype='object')

# %%
sales[['Region','Country']]
# Out:
#                                Region                Country
# 0               Australia and Oceania                 Tuvalu
# 1   Central America and the Caribbean                Grenada
# 2                              Europe                 Russia
# 3                  Sub_Saharan Africa  Sao Tome and Principe
# 4                  Sub_Saharan Africa                 Rwanda
# ..                                ...                    ...
# 95                 Sub_Saharan Africa                   Mali
# 96                               Asia               Malaysia
# 97                 Sub_Saharan Africa           Sierra Leone
# 98                      North America                 Mexico
# 99                 Sub_Saharan Africa             Mozambique
#
# [100 rows x 2 columns]

# %%
sales[sales.columns[2]]
# Out:
# 0           Baby Food
# 1              Cereal
# 2     Office Supplies
# 3              Fruits
# 4     Office Supplies
#            ...
# 95            Clothes
# 96             Fruits
# 97         Vegetables
# 98      Personal Care
# 99          Household
# Name: Item_Type, Length: 100, dtype: object

# %%
sales['merge']=sales['Region']+sales['Country']
sales.head()
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
#
#   Sales_Channel Order_Priority Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27-06-10     159.42     2533654.00
# 1        Online              C  15-09-12     117.11      576782.80
# 2       Offline              L  05-08-14     524.96     1158502.59
# 3        Online              C  07-05-14       6.92       75591.66
# 4       Offline              L  02-06-13     524.96     3296425.02
#
#    Total_Profit  Unnamed: 9  Unnamed: 10  \
# 0     951410.50         NaN          NaN
# ...

# %%
a=['abc','bcd','xyz']
for i in a:
    print(i[0])
# Out:
# a
# b
# x

# %%
a='abcdefghijk'
print(a[4:7])
# Out:
# efg

# %%
b=['a','b','c','d','e','f']
print(b[:-4:-1])
# Out:
# ['f', 'e', 'd']

# %%
sales[0:9]
# Out:
#                               Region                Country        Item_Type  \
# 0              Australia and Oceania                 Tuvalu        Baby Food
# 1  Central America and the Caribbean                Grenada           Cereal
# 2                             Europe                 Russia  Office Supplies
# 3                 Sub_Saharan Africa  Sao Tome and Principe           Fruits
# 4                 Sub_Saharan Africa                 Rwanda  Office Supplies
# 5              Australia and Oceania        Solomon Islands        Baby Food
# 6                 Sub_Saharan Africa                 Angola        Household
# 7                 Sub_Saharan Africa           Burkina Faso       Vegetables
# 8                 Sub_Saharan Africa  Republic of the Congo    Personal Care
#
#   Sales_Channel Order_Priority Ship_Date  Unit_Cost  Total_Revenue  \
# 0       Offline              H  27-06-10     159.42     2533654.00
# ...

# %%
sales[-3:]
# Out:
#                 Region       Country      Item_Type Sales_Channel  \
# 97  Sub_Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
# 99  Sub_Saharan Africa    Mozambique      Household       Offline
#
#    Order_Priority Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 97              C  29-06-16      90.93      228779.10      93748.05
# 98              M  08-08-15      56.67      471336.91     144521.02
# 99              L  15-02-12     502.54     3586605.09     889472.91
#
#     Unnamed: 9  Unnamed: 10                           merge
# 97         NaN          NaN  Sub_Saharan AfricaSierra Leone
# 98         NaN          NaN             North AmericaMexico
# 99         NaN          NaN    Sub_Saharan AfricaMozambique

# %%
sales.loc[[0,10],:]
# Out:
#                    Region     Country   Item_Type Sales_Channel  \
# 0   Australia and Oceania      Tuvalu   Baby Food       Offline
# 10                   Asia  Kyrgyzstan  Vegetables        Online
#
#    Order_Priority Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 0               H  27-06-10     159.42     2533654.00     951410.50
# 10              H  07-12-11      90.93       19103.44       7828.12
#
#     Unnamed: 9  Unnamed: 10                        merge
# 0          NaN          NaN  Australia and OceaniaTuvalu
# 10         NaN          NaN               AsiaKyrgyzstan

# %%
newdf=sales.loc[[0,10],['Region','Country']]

# %%
newdf.to_csv('newdata.csv')

# %%
sales.loc[[96,97,98],:]
# Out:
#                 Region       Country      Item_Type Sales_Channel  \
# 96                Asia      Malaysia         Fruits       Offline
# 97  Sub_Saharan Africa  Sierra Leone     Vegetables       Offline
# 98       North America        Mexico  Personal Care       Offline
#
#    Order_Priority Ship_Date  Unit_Cost  Total_Revenue  Total_Profit  \
# 96              L  28-12-11       6.92       58471.11      15103.47
# 97              C  29-06-16      90.93      228779.10      93748.05
# 98              M  08-08-15      56.67      471336.91     144521.02
#
#     Unnamed: 9  Unnamed: 10                           merge
# 96         NaN          NaN                    AsiaMalaysia
# 97         NaN          NaN  Sub_Saharan AfricaSierra Leone
# 98         NaN          NaN             North AmericaMexico

# %%
sales.iloc[2,6]
# Out:
# 524.96

# %%
sales.iloc[2:6,6:9]
# Out:
#    Unit_Cost  Total_Revenue  Total_Profit
# 2     524.96     1158502.59     224598.75
# 3       6.92       75591.66      19525.82
# 4     524.96     3296425.02     639077.50
# 5     159.42      759202.72     285087.64

# %%
sales[sales.Sales_Channel != 'Offline']
# Out:
#                                Region                           Country  \
# 1   Central America and the Caribbean                           Grenada
# 3                  Sub_Saharan Africa             Sao Tome and Principe
# 5               Australia and Oceania                   Solomon Islands
# 7                  Sub_Saharan Africa                      Burkina Faso
# 9                  Sub_Saharan Africa                           Senegal
# 10                               Asia                        Kyrgyzstan
# 12                               Asia                        Bangladesh
# 15                             Europe                          Bulgaria
# 19              Australia and Oceania                        East Timor
# 20                             Europe                            Norway
# 21                             Europe                          Portugal
# 22  Central America and the Caribbean                          Honduras
# ...

# %%
len(sales[(sales.Total_Profit>=170000) & (sales.Total_Revenue>=70000)])
# Out:
# 60

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Region          100 non-null    object
#  1   Country         100 non-null    object
#  2   Item_Type       100 non-null    object
#  3   Sales_Channel   100 non-null    object
#  4   Order_Priority  100 non-null    object
#  5   Ship_Date       100 non-null    object
#  6   Unit_Cost       100 non-null    float64
#  7   Total_Revenue   100 non-null    float64
#  8   Total_Profit    100 non-null    float64
#  9   Unnamed: 9      0 non-null      float64
#  10  Unnamed: 10     0 non-null      float64
#  11  merge           100 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 9.5+ KB

# %%
sales.describe()
# Out:
#         Unit_Cost  Total_Revenue  Total_Profit  Unnamed: 9  Unnamed: 10
# count  100.000000   1.000000e+02  1.000000e+02         0.0          0.0
# mean   191.048000   1.373488e+06  4.416820e+05         NaN          NaN
# std    188.208181   1.460029e+06  4.385379e+05         NaN          NaN
# min      6.920000   4.870260e+03  1.258020e+03         NaN          NaN
# 25%     35.840000   2.687212e+05  1.214436e+05         NaN          NaN
# 50%    107.275000   7.523144e+05  2.907680e+05         NaN          NaN
# 75%    263.330000   2.212045e+06  6.358288e+05         NaN          NaN
# max    524.960000   5.997055e+06  1.719922e+06         NaN          NaN

# %%
newdf1=sales.drop(['Region','Country'],axis=1)
newdf1
# Out:
#           Item_Type Sales_Channel Order_Priority Ship_Date  Unit_Cost  \
# 0         Baby Food       Offline              H  27-06-10     159.42
# 1            Cereal        Online              C  15-09-12     117.11
# 2   Office Supplies       Offline              L  05-08-14     524.96
# 3            Fruits        Online              C  07-05-14       6.92
# 4   Office Supplies       Offline              L  02-06-13     524.96
# ..              ...           ...            ...       ...        ...
# 95          Clothes        Online              M  09-03-11      35.84
# 96           Fruits       Offline              L  28-12-11       6.92
# 97       Vegetables       Offline              C  29-06-16      90.93
# 98    Personal Care       Offline              M  08-08-15      56.67
# 99        Household       Offline              L  15-02-12     502.54
#
#     Total_Revenue  Total_Profit  Unnamed: 9  Unnamed: 10  \
# 0      2533654.00     951410.50         NaN          NaN
# ...

# %%
sales.drop(sales.columns[[0,2]],axis=1)
# Out:
#                   Country Sales_Channel Order_Priority Ship_Date  Unit_Cost  \
# 0                  Tuvalu       Offline              H  27-06-10     159.42
# 1                 Grenada        Online              C  15-09-12     117.11
# 2                  Russia       Offline              L  05-08-14     524.96
# 3   Sao Tome and Principe        Online              C  07-05-14       6.92
# 4                  Rwanda       Offline              L  02-06-13     524.96
# ..                    ...           ...            ...       ...        ...
# 95                   Mali        Online              M  09-03-11      35.84
# 96               Malaysia       Offline              L  28-12-11       6.92
# 97           Sierra Leone       Offline              C  29-06-16      90.93
# 98                 Mexico       Offline              M  08-08-15      56.67
# 99             Mozambique       Offline              L  15-02-12     502.54
#
# ...

# %%
sales.drop(sales.loc[:,'Country':'Total_Profit'],axis=1)
# Out:
#                                Region  Unnamed: 9  Unnamed: 10  \
# 0               Australia and Oceania         NaN          NaN
# 1   Central America and the Caribbean         NaN          NaN
# 2                              Europe         NaN          NaN
# 3                  Sub_Saharan Africa         NaN          NaN
# 4                  Sub_Saharan Africa         NaN          NaN
# ..                                ...         ...          ...
# 95                 Sub_Saharan Africa         NaN          NaN
# 96                               Asia         NaN          NaN
# 97                 Sub_Saharan Africa         NaN          NaN
# 98                      North America         NaN          NaN
# 99                 Sub_Saharan Africa         NaN          NaN
#
#                                        merge
# 0                Australia and OceaniaTuvalu
# 1   Central America and the CaribbeanGrenada
# 2                               EuropeRussia
# ...

# %%
df=sales.drop_duplicates()
len(df)
# Out:
# 100

# %%
data={'name':['a','b','c','d','a'],'age':[12,13,14,15,12]}
df1=pd.DataFrame(data)
df1
# Out:
#   name  age
# 0    a   12
# 1    b   13
# 2    c   14
# 3    d   15
# 4    a   12

# %%
df2=df1.drop_duplicates()
df2
# Out:
#   name  age
# 0    a   12
# 1    b   13
# 2    c   14
# 3    d   15

# %%
new_data=df1.sort_values('name',ascending=False)
new_data
# Out:
#   name  age
# 3    d   15
# 2    c   14
# 1    b   13
# 0    a   12
# 4    a   12

# %%
df2=pd.DataFrame({'A':['a','b','c'],'B':['1','2','3']},index=[0,1,2])
df2
# Out:
#    A  B
# 0  a  1
# 1  b  2
# 2  c  3

# %%
df3=pd.DataFrame({'A':['d','e','f'],'B':['4','5','6']},index=[3,4,5])
df3
# Out:
#    A  B
# 3  d  4
# 4  e  5
# 5  f  6

# %%
pd.concat([df2,df3])
# Out:
#    A  B
# 0  a  1
# 1  b  2
# 2  c  3
# 3  d  4
# 4  e  5
# 5  f  6
